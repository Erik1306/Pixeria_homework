# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
rgb_image = cv.imread('rgb_image.jpg')

# %%
rgb_image.shape
# Out:
# (1249, 1024, 3)

# %%
# cv.imshow('rgb_image',rgb_image)

# %%
gray = cv.cvtColor(rgb_image,cv.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (1249, 1024)

# %%
plt.imshow(gray,cmap = 'gray')

# %%
grayscale_avg = (rgb_image[:,:,0] + rgb_image[:,:,1] + rgb_image[:,:,2])/3

# %%
grayscale_avg.shape
# Out:
# (1249, 1024)

# %%
grayscale_avg_img = cv.imwrite('grayscale_avg.jpg',grayscale_avg)

# %%
plt.imshow(grayscale_avg, cmap = 'gray')

# %%
grayscale_luminosity = 0.21*rgb_image[:,:,0] + 0.72*rgb_image[:,:,1] + 0.07*rgb_image[:,:,2]

# %%
grayscale_luminosity_img = cv.imwrite('grayscale_luminosity.jpg',grayscale_avg)

# %%
plt.imshow(grayscale_luminosity, cmap = 'gray')
