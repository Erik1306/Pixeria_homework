# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('rgb_image.jpg')

# %%
plt.imshow(img)
plt.show()

# %%
#red_less 10%
img[:,:,2] = img[:,:,2] - 0.1*img[:,:,2]

# %%
plt.imshow(img)
plt.show()

# %%
#red_less 20%
img[:,:,2] = img[:,:,2] - 0.2*img[:,:,2]

# %%
plt.imshow(img)
plt.show()

# %%
#red_less 50%
img[:,:,2] = img[:,:,2] - 0.5*img[:,:,2]

# %%
plt.imshow(img)
plt.show()

# %%
#red_more 50%
img[:,:,2] = img[:,:,2] + 0.5*img[:,:,2]

# %%
plt.imshow(img)
plt.show()

# %%
#all colors less 20%
img = img[:,:,2] - 0.2*img[:,:,2] + img[:,:,1] - 0.2*img[:,:,1] + img[:,:,0] - 0.2*img[:,:,0]

# %%
plt.imshow(img)
plt.show()
